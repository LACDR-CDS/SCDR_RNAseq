# %% [markdown]
# <a href="https://colab.research.google.com/github/LACDR-CDS/SCDR_RNAseq/blob/main/Session3and4/group5_solution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Session 3 & 4
# In the last session, you learned the basic processing steps for RNA sequencing data. Now you will do the next steps in the analysis of transcriptomics data. First, you will figure out which genes are up- or downregulated between two conditions using differential gene expression analysis. Then you will link this to biological pathways with Gene Ontology enrichment.
#
# # Background
#
# iPSCs are valuable resource to model drug interactions with different tissue and are frequenly used in drug screens to gain insights into drug specificity and toxicity. Tyrosine kinase inhibitors (TKIs) are important drugs in cancer treatment. Unfortunately, certain TKIs may lead to cardiomyopathy as a severe side effect of these drugs.
#
# Here, you will compare the transcriptomes of iPSC-derived cardiomyocites that were treated with two different FDA-approved TKIs, **Doxorubicin** and **Gefinitib**, for 48h to investigate their toxicity and gain insights into the biological pathways potentially leading to cardiotoxicity.
#
# # Objectives
#
# 1. Explore the impact on global gene expression patterns (PCA).
# 2. Identify differentially expressed genes (DEGs) between drug treatment and control.
# 3. Visualized DEGs with volcano plots and heatmaps.
# 4. Perform GO enrichment to determine affected biological pathways.
# 5. Interpret the cardiotoxic potential of these drugs, and what cellular mechansims they might disrupt.

# %% [markdown]
# # Setup
#
# Run the following cells to set up the necessary packages and download the data. If you wish to use a package which is not in the list below, you will need to install and import it yourself.

# %%
#Install packages which are not in the default environment
# %pip install scanpy
# %pip install pydeseq2
# %pip install gseapy
# Out:
# Collecting scanpy
#   Downloading scanpy-1.11.5-py3-none-any.whl.metadata (9.3 kB)
# Collecting anndata>=0.8 (from scanpy)
#   Downloading anndata-0.12.6-py3-none-any.whl.metadata (10.0 kB)
# Requirement already satisfied: h5py>=3.7.0 in /usr/local/lib/python3.12/dist-packages (from scanpy) (3.15.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from scanpy) (1.5.2)
# Collecting legacy-api-wrap>=1.4.1 (from scanpy)
#   Downloading legacy_api_wrap-1.5-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: matplotlib>=3.7.5 in /usr/local/lib/python3.12/dist-packages (from scanpy) (3.10.0)
# Requirement already satisfied: natsort in /usr/local/lib/python3.12/dist-packages (from scanpy) (8.4.0)
# Requirement already satisfied: networkx>=2.7.1 in /usr/local/lib/python3.12/dist-packages (from scanpy) (3.6.1)
# Requirement already satisfied: numba!=0.62.0rc1,>=0.57.1 in /usr/local/lib/python3.12/dist-packages (from scanpy) (0.60.0)
# Requirement already satisfied: numpy>=1.24.1 in /usr/local/lib/python3.12/dist-packages (from scanpy) (2.0.2)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.12/dist-packages (from scanpy) (25.0)
# Requirement already satisfied: pandas>=1.5.3 in /usr/local/lib/python3.12/dist-packages (from scanpy) (2.2.2)
# Requirement already satisfied: patsy!=1.0.0 in /usr/local/lib/python3.12/dist-packages (from scanpy) (1.0.2)
# Requirement already satisfied: pynndescent>=0.5.13 in /usr/local/lib/python3.12/dist-packages (from scanpy) (0.5.13)
# Requirement already satisfied: scikit-learn>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from scanpy) (1.6.1)
# Requirement already satisfied: scipy>=1.8.1 in /usr/local/lib/python3.12/dist-packages (from scanpy) (1.16.3)
# Requirement already satisfied: seaborn>=0.13.2 in /usr/local/lib/python3.12/dist-packages (from scanpy) (0.13.2)
# Collecting session-info2 (from scanpy)
#   Downloading session_info2-0.2.3-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: statsmodels>=0.14.5 in /usr/local/lib/python3.12/dist-packages (from scanpy) (0.14.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from scanpy) (4.67.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from scanpy) (4.15.0)
# Requirement already satisfied: umap-learn>=0.5.6 in /usr/local/lib/python3.12/dist-packages (from scanpy) (0.5.9.post2)
# Collecting array-api-compat>=1.7.1 (from anndata>=0.8->scanpy)
#   Downloading array_api_compat-1.12.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting zarr!=3.0.*,>=2.18.7 (from anndata>=0.8->scanpy)
#   Downloading zarr-3.1.5-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.5->scanpy) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.5->scanpy) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.5->scanpy) (4.61.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.5->scanpy) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.5->scanpy) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.5->scanpy) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.5->scanpy) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba!=0.62.0rc1,>=0.57.1->scanpy) (0.43.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5.3->scanpy) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5.3->scanpy) (2025.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.1.3->scanpy) (3.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.7.5->scanpy) (1.17.0)
# Collecting donfig>=0.8 (from zarr!=3.0.*,>=2.18.7->anndata>=0.8->scanpy)
#   Downloading donfig-0.8.1.post1-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: google-crc32c>=1.5 in /usr/local/lib/python3.12/dist-packages (from zarr!=3.0.*,>=2.18.7->anndata>=0.8->scanpy) (1.7.1)
# Collecting numcodecs>=0.14 (from zarr!=3.0.*,>=2.18.7->anndata>=0.8->scanpy)
#   Downloading numcodecs-0.16.5-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (3.4 kB)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from donfig>=0.8->zarr!=3.0.*,>=2.18.7->anndata>=0.8->scanpy) (6.0.3)
# Downloading scanpy-1.11.5-py3-none-any.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 48.1 MB/s eta 0:00:00
# Downloading anndata-0.12.6-py3-none-any.whl (172 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 172.3/172.3 kB 5.0 MB/s eta 0:00:00
# Downloading legacy_api_wrap-1.5-py3-none-any.whl (10 kB)
# Downloading session_info2-0.2.3-py3-none-any.whl (16 kB)
# Downloading array_api_compat-1.12.0-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.2/58.2 kB 2.3 MB/s eta 0:00:00
# Downloading zarr-3.1.5-py3-none-any.whl (284 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 284.1/284.1 kB 12.1 MB/s eta 0:00:00
# Downloading donfig-0.8.1.post1-py3-none-any.whl (21 kB)
# Downloading numcodecs-0.16.5-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (9.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.2/9.2 MB 41.8 MB/s eta 0:00:00
# Installing collected packages: session-info2, numcodecs, legacy-api-wrap, donfig, array-api-compat, zarr, anndata, scanpy
# Successfully installed anndata-0.12.6 array-api-compat-1.12.0 donfig-0.8.1.post1 legacy-api-wrap-1.5 numcodecs-0.16.5 scanpy-1.11.5 session-info2-0.2.3 zarr-3.1.5
# Collecting pydeseq2
#   Downloading pydeseq2-0.5.3-py3-none-any.whl.metadata (9.0 kB)
# Requirement already satisfied: anndata>=0.11.0 in /usr/local/lib/python3.12/dist-packages (from pydeseq2) (0.12.6)
# Collecting formulaic-contrasts>=0.2.0 (from pydeseq2)
#   Downloading formulaic_contrasts-1.0.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting formulaic>=1.0.2 (from pydeseq2)
#   Downloading formulaic-1.2.1-py3-none-any.whl.metadata (7.0 kB)
# Requirement already satisfied: matplotlib>=3.9.0 in /usr/local/lib/python3.12/dist-packages (from pydeseq2) (3.10.0)
# Requirement already satisfied: numpy>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from pydeseq2) (2.0.2)
# Requirement already satisfied: pandas>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from pydeseq2) (2.2.2)
# Requirement already satisfied: scikit-learn>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from pydeseq2) (1.6.1)
# Requirement already satisfied: scipy>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from pydeseq2) (1.16.3)
# Requirement already satisfied: array-api-compat>=1.7.1 in /usr/local/lib/python3.12/dist-packages (from anndata>=0.11.0->pydeseq2) (1.12.0)
# Requirement already satisfied: h5py>=3.8 in /usr/local/lib/python3.12/dist-packages (from anndata>=0.11.0->pydeseq2) (3.15.1)
# Requirement already satisfied: legacy-api-wrap in /usr/local/lib/python3.12/dist-packages (from anndata>=0.11.0->pydeseq2) (1.5)
# Requirement already satisfied: natsort in /usr/local/lib/python3.12/dist-packages (from anndata>=0.11.0->pydeseq2) (8.4.0)
# Requirement already satisfied: packaging>=24.2 in /usr/local/lib/python3.12/dist-packages (from anndata>=0.11.0->pydeseq2) (25.0)
# Requirement already satisfied: zarr!=3.0.*,>=2.18.7 in /usr/local/lib/python3.12/dist-packages (from anndata>=0.11.0->pydeseq2) (3.1.5)
# Collecting interface-meta>=1.2.0 (from formulaic>=1.0.2->pydeseq2)
#   Downloading interface_meta-1.3.0-py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: narwhals>=1.17 in /usr/local/lib/python3.12/dist-packages (from formulaic>=1.0.2->pydeseq2) (2.13.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.12/dist-packages (from formulaic>=1.0.2->pydeseq2) (4.15.0)
# Requirement already satisfied: wrapt>=1.0 in /usr/local/lib/python3.12/dist-packages (from formulaic>=1.0.2->pydeseq2) (2.0.1)
# Collecting session-info (from formulaic-contrasts>=0.2.0->pydeseq2)
#   Downloading session_info-1.0.1-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9.0->pydeseq2) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9.0->pydeseq2) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9.0->pydeseq2) (4.61.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9.0->pydeseq2) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9.0->pydeseq2) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9.0->pydeseq2) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9.0->pydeseq2) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.2.0->pydeseq2) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.2.0->pydeseq2) (2025.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.4.0->pydeseq2) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.4.0->pydeseq2) (3.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.9.0->pydeseq2) (1.17.0)
# Requirement already satisfied: donfig>=0.8 in /usr/local/lib/python3.12/dist-packages (from zarr!=3.0.*,>=2.18.7->anndata>=0.11.0->pydeseq2) (0.8.1.post1)
# Requirement already satisfied: google-crc32c>=1.5 in /usr/local/lib/python3.12/dist-packages (from zarr!=3.0.*,>=2.18.7->anndata>=0.11.0->pydeseq2) (1.7.1)
# Requirement already satisfied: numcodecs>=0.14 in /usr/local/lib/python3.12/dist-packages (from zarr!=3.0.*,>=2.18.7->anndata>=0.11.0->pydeseq2) (0.16.5)
# Collecting stdlib_list (from session-info->formulaic-contrasts>=0.2.0->pydeseq2)
#   Downloading stdlib_list-0.12.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from donfig>=0.8->zarr!=3.0.*,>=2.18.7->anndata>=0.11.0->pydeseq2) (6.0.3)
# Downloading pydeseq2-0.5.3-py3-none-any.whl (48 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.4/48.4 kB 2.5 MB/s eta 0:00:00
# Downloading formulaic-1.2.1-py3-none-any.whl (117 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.3/117.3 kB 6.6 MB/s eta 0:00:00
# Downloading formulaic_contrasts-1.0.0-py3-none-any.whl (10 kB)
# Downloading interface_meta-1.3.0-py3-none-any.whl (14 kB)
# Downloading session_info-1.0.1-py3-none-any.whl (9.1 kB)
# Downloading stdlib_list-0.12.0-py3-none-any.whl (87 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.6/87.6 kB 4.7 MB/s eta 0:00:00
# Installing collected packages: stdlib_list, interface-meta, session-info, formulaic, formulaic-contrasts, pydeseq2
# Successfully installed formulaic-1.2.1 formulaic-contrasts-1.0.0 interface-meta-1.3.0 pydeseq2-0.5.3 session-info-1.0.1 stdlib_list-0.12.0
# Collecting gseapy
#   Downloading gseapy-1.1.11-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.13.0 in /usr/local/lib/python3.12/dist-packages (from gseapy) (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from gseapy) (1.16.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from gseapy) (2.2.2)
# Requirement already satisfied: matplotlib>=2.2 in /usr/local/lib/python3.12/dist-packages (from gseapy) (3.10.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from gseapy) (2.32.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=2.2->gseapy) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=2.2->gseapy) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=2.2->gseapy) (4.61.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=2.2->gseapy) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=2.2->gseapy) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=2.2->gseapy) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=2.2->gseapy) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=2.2->gseapy) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->gseapy) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->gseapy) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->gseapy) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->gseapy) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->gseapy) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->gseapy) (2025.11.12)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=2.2->gseapy) (1.17.0)
# Downloading gseapy-1.1.11-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (605 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 605.3/605.3 kB 32.0 MB/s eta 0:00:00
# Installing collected packages: gseapy
# Successfully installed gseapy-1.1.11

# %%
#Import packages
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scanpy as sc
import anndata as ad
import os
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from pydeseq2.dds import DeseqDataSet
from pydeseq2.ds import DeseqStats
import pickle
import gseapy

# %%
group_number = 5


#Make data directory if it does not exist
os.makedirs("data", exist_ok=True)
os.makedirs("plots", exist_ok=True)

#Download datasets in the data folder
# !wget https://raw.githubusercontent.com/LACDR-CDS/SCDR_Bioinformatics_Practical/refs/heads/main/Session3and4/data/counts_group{group_number}.txt -O data/group{group_number}.txt
# !wget https://raw.githubusercontent.com/LACDR-CDS/SCDR_Bioinformatics_Practical/refs/heads/main/Session3and4/data/metadata_group{group_number}.txt -O data/group{group_number}_metadata.csv
# Out:
# --2025-12-15 15:03:24--  https://raw.githubusercontent.com/LACDR-CDS/SCDR_Bioinformatics_Practical/refs/heads/main/Session3and4/data/counts_group5.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2357755 (2.2M) [text/plain]
# Saving to: ‘data/group5.txt’
#
# data/group5.txt     100%[===================>]   2.25M  --.-KB/s    in 0.01s
#
# 2025-12-15 15:03:25 (166 MB/s) - ‘data/group5.txt’ saved [2357755/2357755]
#
# --2025-12-15 15:03:25--  https://raw.githubusercontent.com/LACDR-CDS/SCDR_Bioinformatics_Practical/refs/heads/main/Session3and4/data/metadata_group5.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 785 [text/plain]
# Saving to: ‘data/group5_metadata.csv’
#
# data/group5_metadat 100%[===================>]     785  --.-KB/s    in 0s
#
# 2025-12-15 15:03:25 (48.2 MB/s) - ‘data/group5_metadata.csv’ saved [785/785]

# %% [markdown]
# # Data import
# Read in your counts and metadata table like you learned in session 2.
# - How many samples do you have? Are there replicates?

# %%
count_table = pd.read_csv("data/group5.txt", sep="\t", index_col = 0)
count_table
# Out:
#              CTRL_1  CTRL_2  CTRL_3  CTRL_4  CTRL_5  CTRL_6  CTRL_7  CTRL_8  \
# DDX11L1           0       0       0       0       0       0       0       0
# WASH7P           59      13      21      42     152      43     118      35
# MIR6859-1         0       2       1       0       0       4       9       3
# MIR1302-2HG       0       0       0       0       4       0       0       0
# MIR1302-2         0       0       0       0       0       0       0       0
# ...             ...     ...     ...     ...     ...     ...     ...     ...
# ND6           40897   29946   40197   43915   42077   20136   59381   41136
# TRNE              4       0       0       0       0       0       0       0
# CYTB         104482   79893  113648  107667  100521   68123  175119  119598
# TRNT              0       0       0       2       0       0       0       0
# TRNP            736     487     612    1622     435     253     602     416
#
#              CTRL_9  CTRL_10  CTRL_11   DOX_1   DOX_2   DOX_3   GEF_1   GEF_2  \
# DDX11L1           0        0        0       0       0       0       0       0
# WASH7P           36       83       27      64      77      41      22      40
# MIR6859-1         3        5        6      13      12      11       2       3
# MIR1302-2HG       0        0        0       0       1       0       0       1
# MIR1302-2         0        0        0       0       0       0       0       0
# ...             ...      ...      ...     ...     ...     ...     ...     ...
# ND6           49069    80854    34107   54961   61237   64244   35113   60571
# TRNE              1        2        0       0       0       0       0       0
# CYTB         138978   236109    99562  141777  150432  176396  106566  159021
# TRNT              0        1        0       0       0       0       0       0
# TRNP            526      965      338    2829    1722    3322     456     558
#
#              GEF_3
# DDX11L1          0
# WASH7P          34
# MIR6859-1        7
# MIR1302-2HG      0
# MIR1302-2        0
# ...            ...
# ND6          22651
# TRNE             0
# CYTB         72299
# TRNT             0
# TRNP           363
#
# [42844 rows x 17 columns]

# %%
print(count_table.shape)
# Out:
# (42844, 17)

# %%
metadata_table = pd.read_csv("data/group5_metadata.csv", sep='\t', index_col = 0)
metadata_table
# Out:
#            treatment Concentration cell_line       cell_type  replicate
# CTRL_1       Control           0nM     MSN09  cardiomyocytes          1
# CTRL_2       Control           0nM     MSN09  cardiomyocytes          2
# CTRL_3       Control           0nM     MSN09  cardiomyocytes          3
# CTRL_4       Control           0nM     MSN09  cardiomyocytes          4
# CTRL_5       Control           0nM     MSN09  cardiomyocytes          5
# CTRL_6       Control           0nM     MSN09  cardiomyocytes          6
# CTRL_7       Control           0nM     MSN09  cardiomyocytes          7
# CTRL_8       Control           0nM     MSN09  cardiomyocytes          8
# CTRL_9       Control           0nM     MSN09  cardiomyocytes          9
# CTRL_10      Control           0nM     MSN09  cardiomyocytes         10
# CTRL_11      Control           0nM     MSN09  cardiomyocytes         11
# DOX_1    Doxorubicin           1uM     MSN09  cardiomyocytes          1
# DOX_2    Doxorubicin           1uM     MSN09  cardiomyocytes          2
# DOX_3    Doxorubicin           1uM     MSN09  cardiomyocytes          3
# GEF_1      Gefitinib           1uM     MSN09  cardiomyocytes          1
# GEF_2      Gefitinib           1uM     MSN09  cardiomyocytes          2
# GEF_3      Gefitinib           1uM     MSN09  cardiomyocytes          3

# %% [markdown]
# **Solution**
# - There are 20 samples and 3 conditions.
# - There are 11 controls, and 3 replicates each per drug treatment (Doxorubicin and Gefinitib)

# %% [markdown]
# # Filtering
#
# - How many genes do you have before and after filtering?

# %%
print("Genes before filtering:", count_table.shape[0])
# Out:
# Genes before filtering: 42844

# %%
gene_count_sums = count_table.sum(axis=1)
print(gene_count_sums)
# Out:
# DDX11L1              0
# WASH7P             907
# MIR6859-1           81
# MIR1302-2HG          6
# MIR1302-2            0
#                 ...
# ND6             780492
# TRNE                 7
# CYTB           2150191
# TRNT                 3
# TRNP             16242
# Length: 42844, dtype: int64

# %%
filtered_count_table= count_table[gene_count_sums >= 10]
filtered_count_table
# Out:
#               CTRL_1  CTRL_2  CTRL_3  CTRL_4  CTRL_5  CTRL_6  CTRL_7  CTRL_8  \
# WASH7P            59      13      21      42     152      43     118      35
# MIR6859-1          0       2       1       0       0       4       9       3
# LOC124900384       7       8       5       0       0       9      11       1
# LOC729737        262     228     282     167     620     379     813     305
# LOC100996442      35      25      25      35     161      43      88      18
# ...              ...     ...     ...     ...     ...     ...     ...     ...
# ND4           172744  121450  170940  169142  128823  100528  253820  162982
# ND5           120786   88007  117930   96700   65350   74934  171519  123898
# ND6            40897   29946   40197   43915   42077   20136   59381   41136
# CYTB          104482   79893  113648  107667  100521   68123  175119  119598
# TRNP             736     487     612    1622     435     253     602     416
#
#               CTRL_9  CTRL_10  CTRL_11   DOX_1   DOX_2   DOX_3   GEF_1  \
# WASH7P            36       83       27      64      77      41      22
# MIR6859-1          3        5        6      13      12      11       2
# LOC124900384       4        7        1       0       2       0       2
# LOC729737        376      556      183     172     416      69     320
# LOC100996442      26       62       33      45      86      64      32
# ...              ...      ...      ...     ...     ...     ...     ...
# ND4           192146   345417   146675  234705  220858  237435  151108
# ND5           154593   225641    90053  163685  169472  157074  110951
# ND6            49069    80854    34107   54961   61237   64244   35113
# CYTB          138978   236109    99562  141777  150432  176396  106566
# TRNP             526      965      338    2829    1722    3322     456
#
#                GEF_2   GEF_3
# WASH7P            40      34
# MIR6859-1          3       7
# LOC124900384       3       2
# LOC729737        297     456
# LOC100996442      38      85
# ...              ...     ...
# ND4           248414  102365
# ND5           159365   78549
# ND6            60571   22651
# CYTB          159021   72299
# TRNP             558     363
#
# [26752 rows x 17 columns]

# %%
print("Genes after filtering:", filtered_count_table.shape[0])
# Out:
# Genes after filtering: 26752

# %% [markdown]
# **Solution**
# - There are 42844 genes before filtering and 26752 after.

# %% [markdown]
# # Normalization: counts per million
# Perform normalization to account for differences in sequencing depth among samples.

# %%
total_reads = filtered_count_table.sum(axis = 0)
normalized_count_table = (filtered_count_table /  total_reads) * 1000000
log_transformed_counts = np.log2(normalized_count_table + 1)

# %% [markdown]
# # Principle component analysis (PCA)
#
# Now explore your data with PCA like you did in the previous session.
# - Which drug do you think has a stronger effect on gene expression based on the clustering pattern?
# - How do you expect the size of the effect to impact gene expression profiles? Do you expect a difference in up- or downregulated genes?

# %%
scaler = StandardScaler()

scaled_table = scaler.fit_transform(log_transformed_counts.T)

pca = PCA()

pca_result_matrix= pca.fit_transform(scaled_table)

# %%
scaler = StandardScaler()

scaled_table = scaler.fit_transform(log_transformed_counts.T)

pca = PCA()

pca_result_matrix= pca.fit_transform(scaled_table)

# %%
plot_df = pd.DataFrame({

 "PC1": pca_result_matrix[:, 0],

 "PC2": pca_result_matrix[:, 1],

 "condition": metadata_table["treatment"].values
 })

# %%
plt.figure(figsize=(3, 3))
sns.scatterplot(

data=plot_df,

x="PC1", y="PC2",

hue="condition"

)

plt.xlabel(f"PC1 ({pca.explained_variance_ratio_[0]*100:.1f}%)")
plt.ylabel(f"PC2 ({pca.explained_variance_ratio_[1]*100:.1f}%)")
plt.title("PCA of RNA-seq Samples")
plt.legend(bbox_to_anchor=(1, 1))
plt.savefig("plots/PCA_session2.png", dpi = 200)

plt.show()

# %% [markdown]
# **Solution**
# - Doxorubicin is expected to have a higher effect on gene expression, as the samples form a seperate cluster from the controls. Genifitib instead clusters with the control samples, so a smaller effect on gene expression is expected.
# - Doxorubicin is expected to have more up- and downregulated genes than Genfinitib.

# %% [markdown]
# # Differential gene expression
#
# Now you can perform differential gene expression analysis using the DEseq2 method. This method allows to find genes with significant expression differences (up- or downregulated) bewteen two conditions.
# - Your goal is to investigate the effect of the drugs on cardiomyocyte differentiation. Which samples do you need to compare?
# - Then, build you DEseq object(s) and run the analysis. *Make sure you use the raw counts for this (not the counts per million normalized counts used for PCA), since DEseq does it's own internal normalization method.*
# - Analyse the output of your DEseq analysis. Does the number of differentially expressed genes match your expectiations from the PCA analysis?
# - Look up the most up/downregulated genes between the conditions. Visualise the first 10 in a volcano plot or heatmap. Can you draw any conclusion from this about the drug effect?

# %% [markdown]
# **Solution**
# - We want to compare each drug with the control. Therefore, we need to do two seperate DE analysis, once Doxorubicin vs Ctrl and then Gefinitib vs Ctrl.

# %%
drug = "Doxorubicin"

metadata_df_filtered_dox = metadata_table[metadata_table["treatment"].isin([drug, "Control"])]
counts_filtered_dox = filtered_count_table[metadata_df_filtered_dox.index]

# Create DESeq2 object
deseq_object = DeseqDataSet(
    counts=counts_filtered_dox.T,
    metadata=metadata_df_filtered_dox,
    design_factors="treatment",
)

# Run DESeq2
deseq_object.deseq2()

# Get results for the current contrast
stat_res_dox = DeseqStats(
    deseq_object, contrast=("treatment", "Doxorubicin", "Control")
)
stat_res_dox.summary()
results_df_dox = stat_res_dox.results_df
# Out:
# /tmp/ipython-input-3200602812.py:7: DeprecationWarning: design_factors is deprecated and will soon be removed.Please consider providing a formulaic formula using the design argumentinstead.
#   deseq_object = DeseqDataSet(
# Fitting size factors...
# ... done in 0.04 seconds.
# Using None as control genes, passed at DeseqDataSet initialization
# Fitting dispersions...
# ... done in 44.21 seconds.
#
# Fitting dispersion trend curve...
# ... done in 1.24 seconds.
#
# Fitting MAP dispersions...
# ... done in 51.93 seconds.
#
# Fitting LFCs...
# ... done in 33.80 seconds.
#
# Calculating cook's distance...
# ... done in 0.18 seconds.
#
# Replacing 167 outlier genes.
#
# Fitting dispersions...
# ... done in 0.79 seconds.
#
# Fitting MAP dispersions...
# ... done in 1.15 seconds.
#
# Fitting LFCs...
# ... done in 0.98 seconds.
#
# Running Wald tests...
# ... done in 10.71 seconds.
# Log2 fold change & Wald test p-value: treatment Doxorubicin vs Control
#                    baseMean  log2FoldChange     lfcSE      stat    pvalue  \
# WASH7P            51.338910       -0.086644  0.404943 -0.213966  0.830574
# MIR6859-1          4.578691        1.676120  0.845594  1.982181  0.047459
# LOC124900384       4.191673       -3.255476  1.409005 -2.310479  0.020862
# LOC729737        328.610335       -1.083885  0.390117 -2.778361  0.005463
# LOC100996442      47.854603        0.182055  0.411936  0.441948  0.658527
# ...                     ...             ...       ...       ...       ...
# ND4           182211.265595        0.074764  0.215569  0.346821  0.728726
# ND5           125778.503921        0.115623  0.268401  0.430782  0.666627
# ND6            45108.469519        0.168373  0.201419  0.835934  0.403192
# CYTB          124055.191022        0.064987  0.214184  0.303416  0.761573
# TRNP             987.793621        1.713040  0.418877  4.089603  0.000043
#
#                   padj
# WASH7P        0.884233
# MIR6859-1     0.097195
# LOC124900384  0.048811
# LOC729737     0.015259
# LOC100996442  0.754708
# ...                ...
# ND4           0.809296
# ND5           0.761051
# ND6           0.526050
# CYTB          0.834013
# TRNP          0.000199
#
# [26752 rows x 6 columns]

# %%
# Get upregulated and downregulated genes
upregulated_genes_dox = results_df_dox[
    (results_df_dox["log2FoldChange"] > 2) & (results_df_dox["padj"] < 0.05)
]
downregulated_genes_dox = results_df_dox[
    (results_df_dox["log2FoldChange"] < -2) & (results_df_dox["padj"] < 0.05)
]
print(f"    Upregulated genes: {upregulated_genes_dox.shape[0]}")
print(f"    Downregulated genes: {downregulated_genes_dox.shape[0]}")
# Out:
#     Upregulated genes: 3055
#     Downregulated genes: 1314

# %%
plt.scatter(
    results_df_dox.log2FoldChange, -np.log10(results_df_dox.padj), s=8, alpha=0.5
)
plt.axhline(-np.log10(0.05), ls="--", color="grey")
plt.axvline(1, ls="--", color="grey")
plt.axvline(-1, ls="--", color="grey")
plt.xlabel("log2FC (drug vs control)")
plt.ylabel("-log10(FDR)")
plt.title(f"Volcano plot - {drug}")


up = results_df_dox[results_df_dox.log2FoldChange > 1].nsmallest(3, "padj")
down = results_df_dox[results_df_dox.log2FoldChange < -1].nsmallest(3, "padj")

for gene, r in up.iterrows():
  plt.text(r.log2FoldChange, -np.log10(r.padj), gene,
  fontsize=10, color="red")
for gene, r in down.iterrows():
  plt.text(r.log2FoldChange, -np.log10(r.padj), gene,
  fontsize=10, color="red")

plt.show()

# %%
gene_list = results_df_dox[results_df_dox.log2FoldChange > 1].nsmallest(10, "padj").index

subset = log_transformed_counts.loc[log_transformed_counts.index.intersection(gene_list)].T
subset = subset[gene_list]

plt.figure(figsize=(len(subset), 4.5))

sns.heatmap(subset, cmap="RdBu_r", linecolor = "white", linewidth = 0.5, cbar_kws={"label": "log2-normalized read counts"}
)
plt.title("Top 10 Upregulated Genes in Doxorubicin vs Control")
plt.xlabel("Genes")
plt.ylabel("Samples")
plt.tight_layout()
plt.savefig("plots/heatmap_session2.png", dpi = 200)
plt.show()

# %%
gene_list = results_df_dox[results_df_dox.log2FoldChange < 1].nsmallest(10, "padj").index

subset = log_transformed_counts.loc[log_transformed_counts.index.intersection(gene_list)].T
subset = subset[gene_list]

plt.figure(figsize=(len(subset), 4.5))

sns.heatmap(subset, cmap="RdBu_r", linecolor = "white", linewidth = 0.5, cbar_kws={"label": "log2-normalized read counts"}
)
plt.title("Top 10 Downregulated Genes in Doxorubicin vs Control")
plt.xlabel("Genes")
plt.ylabel("Samples")
plt.tight_layout()
plt.savefig("plots/heatmap_session2.png", dpi = 200)
plt.show()

# %% [markdown]
# **Solution**
# Now repeat the analysis for Gefinitib

# %%
drug = "Gefitinib"

metadata_df_filtered_gef = metadata_table[metadata_table["treatment"].isin([drug, "Control"])]
counts_filtered_gef = filtered_count_table[metadata_df_filtered_gef.index]

# Create DESeq2 object
deseq_object = DeseqDataSet(
    counts=counts_filtered_gef.T,
    metadata=metadata_df_filtered_gef,
    design_factors="treatment",
)

# Run DESeq2
deseq_object.deseq2()

# Get results for the current contrast
stat_res_gef = DeseqStats(deseq_object, contrast=("treatment", "Gefitinib", "Control"))
stat_res_gef.summary()
results_df_gef = stat_res_gef.results_df
# Out:
# Using None as control genes, passed at DeseqDataSet initialization
# /tmp/ipython-input-1942930641.py:7: DeprecationWarning: design_factors is deprecated and will soon be removed.Please consider providing a formulaic formula using the design argumentinstead.
#   deseq_object = DeseqDataSet(
# Fitting size factors...
# ... done in 0.03 seconds.
#
# Fitting dispersions...
# ... done in 54.59 seconds.
#
# Fitting dispersion trend curve...
# ... done in 2.65 seconds.
#
# Fitting MAP dispersions...
# ... done in 40.63 seconds.
#
# Fitting LFCs...
# ... done in 23.36 seconds.
#
# Calculating cook's distance...
# ... done in 0.06 seconds.
#
# Replacing 95 outlier genes.
#
# Fitting dispersions...
# ... done in 0.26 seconds.
#
# Fitting MAP dispersions...
# ... done in 0.28 seconds.
#
# Fitting LFCs...
# ... done in 0.22 seconds.
#
# Running Wald tests...
# ... done in 7.56 seconds.
# Log2 fold change & Wald test p-value: treatment Gefitinib vs Control
#                    baseMean  log2FoldChange     lfcSE      stat    pvalue  \
# WASH7P            45.019869       -0.331790  0.409523 -0.810186  0.417833
# MIR6859-1          3.275361        0.782730  0.987807  0.792392  0.428132
# LOC124900384       4.295718       -0.745748  1.004548 -0.742372  0.457862
# LOC729737        356.604165        0.361360  0.302452  1.194770  0.232177
# LOC100996442      46.486884        0.559636  0.435215  1.285886  0.198483
# ...                     ...             ...       ...       ...       ...
# ND4           170181.967212        0.252218  0.240110  1.050428  0.293521
# ND5           117310.524575        0.282055  0.276652  1.019529  0.307952
# ND6            41136.920981        0.198988  0.236175  0.842546  0.399483
# CYTB          115800.183916        0.240913  0.227706  1.058001  0.290055
# TRNP             590.362346       -0.150843  0.403098 -0.374209  0.708249
#
#                   padj
# WASH7P        0.822985
# MIR6859-1          NaN
# LOC124900384       NaN
# LOC729737     0.733374
# LOC100996442  0.712411
# ...                ...
# ND4           0.762553
# ND5           0.769950
# ND6           0.815850
# CYTB          0.760849
# TRNP          0.922762
#
# [26752 rows x 6 columns]

# %%
# Get upregulated and downregulated genes
upregulated_genes_gef = results_df_gef[
    (results_df_gef["log2FoldChange"] > 2) & (results_df_gef["padj"] < 0.05)
]
downregulated_genes_gef = results_df_gef[
    (results_df_gef["log2FoldChange"] < -2) & (results_df_gef["padj"] < 0.05)
]
print(f"    Upregulated genes: {upregulated_genes_gef.shape[0]}")
print(f"    Downregulated genes: {downregulated_genes_gef.shape[0]}")
# Out:
#     Upregulated genes: 0
#     Downregulated genes: 15

# %%
plt.scatter(
    results_df_gef.log2FoldChange, -np.log10(results_df_gef.padj), s=8, alpha=0.5
)
plt.axhline(-np.log10(0.05), ls="--", color="grey")
plt.axvline(1, ls="--", color="grey")
plt.axvline(-1, ls="--", color="grey")
plt.xlabel("log2FC (drug vs control)")
plt.ylabel("-log10(FDR)")
plt.title(f"Volcano plot - {drug}")


up = results_df_gef[results_df_gef.log2FoldChange > 1].nsmallest(3, "padj")
down = results_df_gef[results_df_gef.log2FoldChange < -1].nsmallest(3, "padj")

for gene, r in up.iterrows():
  plt.text(r.log2FoldChange, -np.log10(r.padj), gene,
  fontsize=10, color="red")
for gene, r in down.iterrows():
  plt.text(r.log2FoldChange, -np.log10(r.padj), gene,
  fontsize=10, color="red")

plt.show()

# %%
gene_list = results_df_gef[results_df_gef.log2FoldChange < 1].nsmallest(10, "padj").index

subset = log_transformed_counts.loc[log_transformed_counts.index.intersection(gene_list)].T
subset = subset[gene_list]

plt.figure(figsize=(len(subset), 4.5))

sns.heatmap(subset, cmap="RdBu_r", linecolor = "white", linewidth = 0.5, cbar_kws={"label": "log2-normalized read counts"}
)
plt.title("Top 10 Downregulated Genes in Gefinitib vs Control")
plt.xlabel("Genes")
plt.ylabel("Samples")
plt.tight_layout()
plt.savefig("plots/heatmap_session2.png", dpi = 200)
plt.show()

# %% [markdown]
# **Solution**
# - There are many DE genes for Epirubicin, but only 11 DE genes for Gefinitib. Therefore, we would predict that Epirubicin is more toxic to cardiomyocites.
# - The few genes that show as up/downregualted for Gefinitib are likely an artifact, since the still are more similarly expressed to control compared to Epirubicin treatment.

# %% [markdown]
# # Gene Ontology enrichment
#
# Now, you can start interpreting the lists of genes you get from the DEseq analysis and learn if there are any biological pathways that are effected by the drug treatment.
# - Use the cheat sheet to perform a GO enrichment analysis on the upregulated and dowregulated genes from your DEseq analysis. Which pathways can you see?
# - Based on this analysis, do you think either of the drugs you tested are cardiotoxic? Which cellular mechanisms do they disrupt?

# %%
GO_databases = [
    "GO_Biological_Process_2025",
    "GO_Cellular_Component_2025",
    "GO_Molecular_Function_2025",
]

# %%
import time

go_upr_results_dox = {}
go_dwr_results_dox = {}

for db in GO_databases:
    try:
        print(f"    {db}")

        # Upregulated genes
        enr_upr = gseapy.enrichr(
            gene_list=upregulated_genes_dox.index.tolist(),
            gene_sets=db,
            outdir=None,
            cutoff=0.05,
        )
        go_upr_results_dox[db] = enr_upr.res2d

        # Downregulated genes
        enr_dwr = gseapy.enrichr(
            gene_list=downregulated_genes_dox.index.tolist(),
            gene_sets=db,
            outdir=None,
            cutoff=0.05,
        )
        go_dwr_results_dox[db] = enr_dwr.res2d

    except Exception as e:
        time.sleep(30)  # Wait longer if there's an error
# Out:
#     GO_Biological_Process_2025
#     GO_Cellular_Component_2025
#     GO_Molecular_Function_2025

# %%
print(go_upr_results_dox)
print(go_dwr_results_dox)
# Out:
# {'GO_Biological_Process_2025':                         Gene_set  \
# 0     GO_Biological_Process_2025
# 1     GO_Biological_Process_2025
# 2     GO_Biological_Process_2025
# 3     GO_Biological_Process_2025
# 4     GO_Biological_Process_2025
# ...                          ...
# 3520  GO_Biological_Process_2025
# 3521  GO_Biological_Process_2025
# 3522  GO_Biological_Process_2025
# 3523  GO_Biological_Process_2025
# 3524  GO_Biological_Process_2025
#
#                                                    Term Overlap   P-value  \
# 0     Peripheral Nervous System Neuron Development (...     4/5  0.002386
# 1     TRAIL-activated Apoptotic Signaling Pathway (G...     4/8  0.022713
# 2     Cell Differentiation Involved in Metanephros D...     4/8  0.022713
# 3     Regulation of Nephron Tubule Epithelial Cell D...     4/8  0.022713
# 4         Sensory Perception of Sour Taste (GO:0050915)     4/8  0.022713
# ...                                                 ...     ...       ...
# 3520          Mitotic Spindle Organization (GO:0007052)    1/90  0.999996
# 3521  Endoplasmic Reticulum to Golgi Vesicle-Mediate...   1/112  0.999996
# 3522               Cytoplasmic Translation (GO:0002181)   1/101  0.999996
# 3523                mRNA Metabolic Process (GO:0016071)   1/101  0.999996
# 3524  Regulation of mRNA Splicing, via Spliceosome (...    1/97  0.999996
#
#       Adjusted P-value  Old P-value  Old Adjusted P-value  Odds Ratio  \
# 0             0.999996            0                     0   22.214356
# 1             0.999996            0                     0    5.552606
# 2             0.999996            0                     0    5.552606
# 3             0.999996            0                     0    5.552606
# 4             0.999996            0                     0    5.552606
# ...                ...          ...                   ...         ...
# 3520          0.999996            0                     0    0.062015
# 3521          0.999996            0                     0    0.049659
# 3522          0.999996            0                     0    0.055157
# 3523          0.999996            0                     0    0.055157
# 3524          0.999996            0                     0    0.057469
#
#       Combined Score                               Genes
# 0       1.341356e+02             ISL2;POU4F1;RUNX3;RUNX1
# 1       2.101567e+01  SPI1;TNFRSF10C;TNFRSF10B;TNFRSF10A
# 2       2.101567e+01               SALL1;PAX8;STAT1;SIX2
# 3       2.101567e+01                 PAX8;LHX1;LIF;GATA3
# 4       2.101567e+01          SCNN1D;PKD2L1;PKD1L3;ASIC2
# ...              ...                                 ...
# 3520    2.405614e-07                                PLK3
# 3521    1.911751e-07                               TMED6
# 3522    2.072771e-07                               RPS10
# 3523    2.072771e-07                                ERN1
# 3524    2.157608e-07                               CELF6
#
# [3525 rows x 10 columns], 'GO_Cellular_Component_2025':                        Gene_set  \
# 0    GO_Cellular_Component_2025
# 1    GO_Cellular_Component_2025
# 2    GO_Cellular_Component_2025
# 3    GO_Cellular_Component_2025
# 4    GO_Cellular_Component_2025
# ..                          ...
# 291  GO_Cellular_Component_2025
# 292  GO_Cellular_Component_2025
# 293  GO_Cellular_Component_2025
# 294  GO_Cellular_Component_2025
# 295  GO_Cellular_Component_2025
#
#                                                   Term Overlap   P-value  \
# 0    ATPase Dependent Transmembrane Transport Compl...     3/6  0.049623
# 1    ATP-binding Cassette (ABC) Transporter Complex...     2/5  0.169860
# 2                      Astrocyte End-Foot (GO:0097450)     2/5  0.169860
# 3    Asymmetric, Glutamatergic, Excitatory Synapse ...     2/5  0.169860
# 4                            Chromocenter (GO:0010369)     2/5  0.169860
# ..                                                 ...     ...       ...
# 291                            Chromosome (GO:0005694)   6/179  0.999995
# 292                       Mitotic Spindle (GO:0072686)   5/155  0.999996
# 293               Clathrin-Coated Vesicle (GO:0030136)    1/84  0.999996
# 294               Azurophil Granule Lumen (GO:0035578)    1/89  0.999996
# 295                    Nuclear Chromosome (GO:0000228)    1/90  0.999996
#
#      Adjusted P-value  Old P-value  Old Adjusted P-value  Odds Ratio  \
# 0            0.999996            0                     0    5.551114
# 1            0.999996            0                     0    3.699531
# 2            0.999996            0                     0    3.699531
# 3            0.999996            0                     0    3.699531
# 4            0.999996            0                     0    3.699531
# ..                ...          ...                   ...         ...
# 291          0.999996            0                     0    0.190780
# 292          0.999996            0                     0    0.183552
# 293          0.999996            0                     0    0.066521
# 294          0.999996            0                     0    0.062723
# 295          0.999996            0                     0    0.062015
#
#      Combined Score                              Genes
# 0      1.667170e+01                 ABCG8;ABCB6;SLC9A1
# 1      6.558465e+00                        ABCG8;ABCB6
# 2      6.558465e+00                      SLC2A13;CLCN2
# 3      6.558465e+00                      SHISA7;SHISA6
# 4      6.558465e+00                        SALL1;SOX30
# ..              ...                                ...
# 291    8.624824e-07    H1-5;MYCL;EMX1;GTF2B;BAZ1A;ELL3
# 292    8.193191e-07  TUBB8;TUBB3;HEPACAM2;PTPN7;ZNF367
# 293    2.888036e-07                                VWF
# 294    2.460577e-07                              FUCA1
# 295    2.405614e-07                              BAZ1A
#
# [296 rows x 10 columns], 'GO_Molecular_Function_2025':                        Gene_set  \
# 0    GO_Molecular_Function_2025
# 1    GO_Molecular_Function_2025
# 2    GO_Molecular_Function_2025
# 3    GO_Molecular_Function_2025
# 4    GO_Molecular_Function_2025
# ..                          ...
# 731  GO_Molecular_Function_2025
# 732  GO_Molecular_Function_2025
# 733  GO_Molecular_Function_2025
# 734  GO_Molecular_Function_2025
# 735  GO_Molecular_Function_2025
#
#                                                   Term Overlap   P-value  \
# 0    Sodium Ion Transmembrane Transporter Activity ...   14/40  0.001659
# 1    Natural Killer Cell Lectin-Like Receptor Bindi...     4/7  0.012903
# 2    pH-gated Monoatomic Ion Channel Activity (GO:0...     4/7  0.012903
# 3    Branched-Chain Amino Acid Transmembrane Transp...     4/9  0.036012
# 4     D-glucose:sodium Symporter Activity (GO:0005412)     3/6  0.049623
# ..                                                 ...     ...       ...
# 731                 Magnesium Ion Binding (GO:0000287)   5/162  0.999996
# 732      Cysteine-Type Peptidase Activity (GO:0008234)   4/147  0.999996
# 733               Deubiquitinase Activity (GO:0101005)   1/111  0.999996
# 734                      Ribosome Binding (GO:0043022)    1/93  0.999996
# 735  Cysteine-Type Deubiquitinase Activity (GO:0004...    1/96  0.999996
#
#      Adjusted P-value  Old P-value  Old Adjusted P-value  Odds Ratio  \
# 0            0.999996            0                     0    2.995801
# 1            0.999996            0                     0    7.403911
# 2            0.999996            0                     0    7.403911
# 3            0.999996            0                     0    4.441822
# 4            0.999996            0                     0    5.551114
# ..                ...          ...                   ...         ...
# 731          0.999996            0                     0    0.175295
# 732          0.999996            0                     0    0.154043
# 733          0.999996            0                     0    0.050113
# 734          0.999996            0                     0    0.059982
# 735          0.999996            0                     0    0.058077
#
#      Combined Score                                              Genes
# 0      1.917744e+01  MCOLN3;SLC23A1;SLC4A11;PKD2L1;SLC5A10;SLC6A20;...
# 1      3.220897e+01                            RAET1G;ULBP2;ULBP1;MICB
# 2      3.220897e+01                           PKD2L1;PKD1L3;ZACN;ASIC2
# 3      1.476414e+01                     SLC43A2;SLC7A8;SLC6A15;SLC6A20
# 4      1.667170e+01                              SLC5A10;SLC5A2;SLC5A3
# ..              ...                                                ...
# 731    7.729723e-07                      ERN1;HPGDS;POLR2A;SPHK1;PDE2A
# 732    6.609073e-07                            CASP10;OTUD6A;CTSW;CTSV
# 733    1.924093e-07                                             OTUD6A
# 734    2.276271e-07                                              CPEB1
# 735    2.183219e-07                                             OTUD6A
#
# [736 rows x 10 columns]}
# {'GO_Biological_Process_2025':                         Gene_set  \
# 0     GO_Biological_Process_2025
# 1     GO_Biological_Process_2025
# 2     GO_Biological_Process_2025
# 3     GO_Biological_Process_2025
# 4     GO_Biological_Process_2025
# ...                          ...
# 3098  GO_Biological_Process_2025
# 3099  GO_Biological_Process_2025
# 3100  GO_Biological_Process_2025
# 3101  GO_Biological_Process_2025
# 3102  GO_Biological_Process_2025
#
#                                                    Term  Overlap  \
# 0                        Heart Contraction (GO:0060047)    22/41
# 1              Striated Muscle Contraction (GO:0006941)    22/55
# 2               Cardiac Muscle Contraction (GO:0060048)    17/34
# 3                       Myofibril Assembly (GO:0030239)    19/51
# 4          Regulation of Heart Contraction (GO:0008016)    22/70
# ...                                                 ...      ...
# 3098  Regulation of DNA-templated Transcription (GO:...  72/2139
# 3099  Positive Regulation of DNA-templated Transcrip...  46/1274
# 3100  Negative Regulation of DNA-templated Transcrip...  33/1006
# 3101  Positive Regulation of Transcription by RNA Po...   31/983
# 3102  Negative Regulation of Transcription by RNA Po...   20/732
#
#            P-value  Adjusted P-value  Old P-value  Old Adjusted P-value  \
# 0     5.977019e-16      1.854669e-12            0                     0
# 1     1.302785e-12      2.021271e-09            0                     0
# 2     5.726595e-12      5.923208e-09            0                     0
# 3     1.925687e-10      1.493852e-07            0                     0
# 4     3.311453e-10      2.055088e-07            0                     0
# ...            ...               ...          ...                   ...
# 3098  9.999929e-01      9.999940e-01            0                     0
# 3099  9.999930e-01      9.999940e-01            0                     0
# 3100  9.999933e-01      9.999940e-01            0                     0
# 3101  9.999937e-01      9.999940e-01            0                     0
# 3102  9.999940e-01      9.999940e-01            0                     0
#
#       Odds Ratio  Combined Score  \
# 0      16.729428      586.423995
# 1       9.624871      263.399193
# 2      14.393986      372.601285
# 3       8.552751      191.329897
# 4       6.611778      144.324949
# ...          ...             ...
# 3098    0.466096        0.000003
# 3099    0.515745        0.000004
# 3100    0.468969        0.000003
# 3101    0.450096        0.000003
# 3102    0.390176        0.000002
#
#                                                   Genes
# 0     MYBPC3;RYR2;TPM1;ATP1A2;SLC8A1;MYL4;SGCD;ACTC1...
# 1     MYBPC3;CHRNA1;RYR2;SMPX;TPM1;ATP1A2;RCSD1;SLC8...
# 2     MYBPC3;RYR2;TPM1;SLC8A1;MYL4;KCNQ1;MYL2;TNNT2;...
# 3     MYBPC3;MYOM1;ADPRHL1;TMOD2;TPM1;LMOD1;MYBPH;MY...
# 4     CYP2J2;RYR2;CAV3;KCNIP1;HSPB7;TPM1;ATP2B4;ANK2...
# ...                                                 ...
# 3098  RHOXF1;THRA;TGFB1I1;ARRB1;HIF3A;LYL1;JPH2;ZNF2...
# 3099  PRKN;MYRF;THRA;TGFB1I1;GATA5;ARRB1;FGF1;FSTL3;...
# 3100  ZNF512B;PRKN;MAGEL2;THRA;EHMT2;FHL2;GATA5;PRIC...
# 3101  PRKN;THRA;GATA5;ARRB1;FGF1;FSTL3;PDZD2;GPER1;S...
# 3102  PRKN;MAGEL2;EDN1;MLIP;CBX5;PARP1;THRA;EHMT2;PL...
#
# [3103 rows x 10 columns], 'GO_Cellular_Component_2025':                        Gene_set  \
# 0    GO_Cellular_Component_2025
# 1    GO_Cellular_Component_2025
# 2    GO_Cellular_Component_2025
# 3    GO_Cellular_Component_2025
# 4    GO_Cellular_Component_2025
# ..                          ...
# 250  GO_Cellular_Component_2025
# 251  GO_Cellular_Component_2025
# 252  GO_Cellular_Component_2025
# 253  GO_Cellular_Component_2025
# 254  GO_Cellular_Component_2025
#
#                                                   Term   Overlap  \
# 0                               Myofibril (GO:0030016)     12/29
# 1                              Sarcolemma (GO:0042383)     13/52
# 2                            Cytoskeleton (GO:0005856)    73/694
# 3                     Spindle Microtubule (GO:0005876)     15/71
# 4             Actin-Based Cell Projection (GO:0098858)     17/88
# ..                                                 ...       ...
# 250                            Chromosome (GO:0005694)     2/179
# 251  Intracellular Membrane-Bounded Organelle (GO:0...  219/5597
# 252                               Nucleus (GO:0005634)  179/4879
# 253                         Nuclear Lumen (GO:0031981)    21/814
# 254                             Nucleolus (GO:0005730)    20/805
#
#           P-value  Adjusted P-value  Old P-value  Old Adjusted P-value  \
# 0    1.119198e-07          0.000029            0                     0
# 1    2.277780e-05          0.002596            0                     0
# 2    4.504595e-05          0.002596            0                     0
# 3    4.717280e-05          0.002596            0                     0
# 4    5.090282e-05          0.002596            0                     0
# ..            ...               ...          ...                   ...
# 250  9.999290e-01          0.999994            0                     0
# 251  9.999915e-01          0.999994            0                     0
# 252  9.999916e-01          0.999994            0                     0
# 253  9.999944e-01          0.999994            0                     0
# 254  9.999944e-01          0.999994            0                     0
#
#      Odds Ratio  Combined Score  \
# 0     10.121442      161.998569
# 1      4.777607       51.071300
# 2      1.711187       17.125263
# 3      3.841554       38.268382
# 4      3.436479       33.971625
# ..          ...             ...
# 250    0.159406        0.000011
# 251    0.494905        0.000004
# 252    0.469302        0.000004
# 253    0.366464        0.000002
# 254    0.352455        0.000002
#
#                                                  Genes
# 0    MYBPC3;MYL7;OBSCN;MYL2;TNNT2;TMOD2;LMOD1;TNNI3...
# 1    POPDC2;RYR2;ANXA8L1;MLIP;CAV3;DYSF;ANK2;SLC8A1...
# 2    RIPOR2;EDA;FAM107A;LMOD1;LDB3;MYLK3;DNALI1;ACT...
# 3    CCDC57;CEP295;PLK1;HAUS4;SKA3;AURKB;SKA1;CENPE...
# 4    RIPOR2;WWOX;VCAM1;ANGPT1;MYO7B;USH1C;MYO7A;ACT...
# ..                                                 ...
# 250                                       CENPE;EXOSC8
# 251  EHMT2;LDLRAD4;MT2A;GJA1;DPF3;CMKLR2;GAMT;KRT4;...
# 252  EHMT2;FAM107A;BUB1B;FGF1;KLHL31;MT2A;GJA1;DPF3...
# 253  CHRM2;MLIP;CBX5;PARP1;PARP2;FBXL22;KIF18B;SAPC...
# 254  CHRM2;CBX5;PARP1;PARP2;FBXL22;KIF18B;SAPCD2;UB...
#
# [255 rows x 10 columns], 'GO_Molecular_Function_2025':                        Gene_set  \
# 0    GO_Molecular_Function_2025
# 1    GO_Molecular_Function_2025
# 2    GO_Molecular_Function_2025
# 3    GO_Molecular_Function_2025
# 4    GO_Molecular_Function_2025
# ..                          ...
# 621  GO_Molecular_Function_2025
# 622  GO_Molecular_Function_2025
# 623  GO_Molecular_Function_2025
# 624  GO_Molecular_Function_2025
# 625  GO_Molecular_Function_2025
#
#                                                   Term  Overlap   P-value  \
# 0                     Tropomyosin Binding (GO:0005523)     6/13  0.000091
# 1              Myosin Heavy Chain Binding (GO:0032036)     5/10  0.000232
# 2       Sodium Channel Regulator Activity (GO:0017080)     8/36  0.001965
# 3                     Calcium Ion Binding (GO:0005509)   35/324  0.002640
# 4    Fibroblast Growth Factor Receptor Binding (GO:...     6/25  0.004769
# ..                                                 ...      ...       ...
# 621  Cis-Regulatory Region Sequence-Specific DNA Bi...  24/1035  0.999994
# 622  Sequence-Specific Double-Stranded DNA Binding ...   18/706  0.999994
# 623         Sequence-Specific DNA Binding (GO:0043565)   17/718  0.999995
# 624                          mRNA Binding (GO:0003729)    4/310  0.999995
# 625           Olfactory Receptor Activity (GO:0004984)    1/379  0.999996
#
#      Adjusted P-value  Old P-value  Old Adjusted P-value  Odds Ratio  \
# 0            0.057155            0                     0   12.240498
# 1            0.072486            0                     0   14.271199
# 2            0.410007            0                     0    4.081820
# 3            0.413125            0                     0    1.741994
# 4            0.535800            0                     0    4.506760
# ..                ...          ...                   ...         ...
# 621          0.999996            0                     0    0.325259
# 622          0.999996            0                     0    0.363332
# 623          0.999996            0                     0    0.336280
# 624          0.999996            0                     0    0.183406
# 625          0.999996            0                     0    0.036888
#
#      Combined Score                                              Genes
# 0      1.138531e+02                 NEBL;TNNT1;TNNT2;TMOD2;LMOD1;LMOD2
# 1      1.194581e+02                         MYBPC3;MYL4;MYL2;MYL3;MYL9
# 2      2.543921e+01    FGF14;CAV3;FXYD1;ATP2B4;FXYD7;FGF12;FGF11;SCN2B
# 3      1.034233e+01  ANXA8L1;TTYH2;DYSF;ITLN1;EFCAB11;SLC8A1;NCALD;...
# 4      2.409160e+01                  FGF5;FGF16;FGF7;FGF14;FGF18;FGF12
# ..              ...                                                ...
# 621    1.941930e-06  MYOG;NFE2;ZSCAN5A;DSCAM;THRA;GATA5;PAX6;HIF3A;...
# 622    2.041876e-06  MYOG;NFE2;ZSCAN5A;RHOXF1;THRA;GATA5;PAX6;ERBB4...
# 623    1.833056e-06  MYOG;NFE2;ZSCAN5A;RHOXF1;MYRF;GATA5;PAX6;PGBD1...
# 624    9.952392e-07                            SRSF3;CELF5;RBMS2;RBMS3
# 625    1.649548e-07                                              OR2W3
#
# [626 rows x 10 columns]}

# %%
for k, v in go_upr_results_dox.items():
    if v is not None:
        print(f"{k}: {v.shape}")

        try:
            gseapy.plot.dotplot(
                v,
                title=f"{k[0], k[1]} \n {k[2]} \n Upregulated pathways \n ",  # Figure title
                cmap="flare",  # Color map
                # top_term=10,  # Number of top terms to show
                # size=5,  # Dot size
                # figsize=(6, 6),  # Figure size (width, height)
                # ofname="dotplot_GO_Biological_Process_2025.png",  # Save figure to file (optional)
            )
            # plt.savefig("dotplot_GO_Biological_Process_2025.png", bbox_inches="tight")
            # plt.show()

        except Exception as e:
            print(f"Error occurred while plotting {k}: {e}")

    else:
        print(f"{k}: None")
# Out:
# GO_Biological_Process_2025: (3525, 10)
# Error occurred while plotting GO_Biological_Process_2025: Warning: No enrich terms when cutoff = 0.05
# GO_Cellular_Component_2025: (296, 10)
# Error occurred while plotting GO_Cellular_Component_2025: Warning: No enrich terms when cutoff = 0.05
# GO_Molecular_Function_2025: (736, 10)
# Error occurred while plotting GO_Molecular_Function_2025: Warning: No enrich terms when cutoff = 0.05

# %%
for k, v in go_dwr_results_dox.items():
    if v is not None:
        print(f"{k}: {v.shape}")

        try:
            gseapy.plot.dotplot(
                v,
                title=f"{k}\n Downregulated pathways \n ",  # Figure title
                cmap="flare",  # Color map
                top_term=10,  # Number of top terms to show
                # size=5,  # Dot size
                # figsize=(6, 6),  # Figure size (width, height)
                # ofname="dotplot_GO_Biological_Process_2025.png",  # Save figure to file (optional)
            )
            # plt.savefig("dotplot_GO_Biological_Process_2025.png", bbox_inches="tight")
            # plt.show()

        except Exception as e:
            print(f"Error occurred while plotting {k}: {e}")

    else:
        print(f"{k}: None")
# Out:
# GO_Biological_Process_2025: (3103, 10)
# GO_Cellular_Component_2025: (255, 10)
# GO_Molecular_Function_2025: (626, 10)
# Error occurred while plotting GO_Molecular_Function_2025: Warning: No enrich terms when cutoff = 0.05

# %%
go_upr_results_gef = {}
go_dwr_results_gef = {}

for db in GO_databases:
    try:
        print(f"    {db}")

        # Upregulated genes
        enr_upr = gseapy.enrichr(
            gene_list=upregulated_genes_gef.index.tolist(),
            gene_sets=db,
            outdir=None,
            cutoff=0.05,
        )
        go_upr_results_gef[db] = enr_upr.res2d

        # Downregulated genes
        enr_dwr = gseapy.enrichr(
            gene_list=downregulated_genes_gef.index.tolist(),
            gene_sets=db,
            outdir=None,
            cutoff=0.05,
        )
        go_dwr_results_gef[db] = enr_dwr.res2d

    except Exception as e:
        time.sleep(30)  # Wait longer if there's an error
# Out:
#     GO_Biological_Process_2025
#     GO_Cellular_Component_2025
#     GO_Molecular_Function_2025

# %%
print(go_upr_results_gef)
print(go_dwr_results_gef)
# Out:
# {}
# {}

# %% [markdown]
# **Solution**
# - Doxorubicin works by blocking Topoisomerase II, intercalating through the DNA and generating ROS. (DNA damage + oxidative stress → apoptosis + loss of contractile identity) This fits with the downregulated pathways which are mostly related to contraction, and the upregulated genes which suggest preparation for apoptosis (TNFRSF10A) and stress-induces transcriptional reprogramming, leading to loss of mature cardiomyocyte identity (CRTAC1)
